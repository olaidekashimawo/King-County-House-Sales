# %% [markdown]
# ## King County Housing Sales
#
# - Student name: Olaide Kashimawo
# - Student pace: Self Paced
# - Scheduled project review date/time:11/30/22
# - Instructor name:Morgan Jones
# - Blog post URL: https://medium.com/@goldprint3/forecasting-at-scale-ada6d8e01b1a

# %% [markdown]
# ![avi-waxman-f9qZuKoZYoY-unsplash%20%282%29.jpg](attachment:avi-waxman-f9qZuKoZYoY-unsplash%20%282%29.jpg)

# %% [markdown]
# ### OVERVIEW

# %% [markdown]
# This dataset comprises the prices of homes that were sold in King County, which is where Seattle is located. It encompasses houses that were purchased between May 2014 and May 2015.

# %% [markdown]
# **id**:  a notation for a house
#
# **date**: Date house was sold
#
# **price**: Price is prediction target
#
# **bedrooms**: Number of Bedrooms/House
#
# **bathrooms**: Number of bathrooms/bedrooms
#
# **sqft_living**: square footage of the home
#
# **sqft_lot**: square footage of the lot
#
# **floors**: Total floors (levels) in house
#
# **waterfront**: House which has a view to a waterfront
#
# **view**: Houses that has been viewed
#
# **condition** :How good the condition is Overall
#
# **grade**: overall grade given to the housing unit, based on King County grading system
#
# **sqft_above**:square footage of house apart from basement
#
# **sqft_basement**: square footage of the basement
#
# **yr_built** :Built Year
#
# **yr_renovated** :Year when house was renovated
#
# **zipcode**:zip code
#
# **lat**: Latitude coordinate
#
# **long**: Longitude coordinate
#
# **sqft_living15** :Living room area in 2015 (means-- some renovations)
#
# **sqft_lot15** :Lotsize area in 2015 (means -- some renovations)

# %% [markdown]
# ### BUSINESS UNDERSTANDING

# %% [markdown]
# To identify the variables affecting house prices, e.g area, number of rooms,bathrooms  and to create a linear model that quantitatively relates house prices with variables such as number of rooms, area and number of bathrooms

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import datetime as dt
import folium
import warnings
import statsmodels.api as sm
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
style.use('ggplot')

plt.style.use('seaborn')
sns.set_theme()
# %matplotlib inline

# %%
pd.set_option('display.max_column',21)

# %% [markdown]
# ### DATA LOAD

# %%
#Load data into notebook
H_Sales = pd.read_csv("data/kc_house_data.csv")

# %%
H_Sales.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
H_Sales.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#checking the shape
H_Sales.shape
# Out:
# (21613, 21)

# %%
#checking the info to Display the data types of each Column (21 columns)
H_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
#To suppress the scientific notation in price
#pd.set_option('display.float_format', lambda x: '%.5f'%x)

# %% [markdown]
# ### Generate descriptive statistics
# Lets summarize the central tendency, dispersion and shape of a dataset's distribution

# %%
H_Sales.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# ### DATA CLEANING
# There are 19 house features plus the price and the id columns, along with 21613 observations.

# %% [markdown]
# ### Categorical vs Continuous Features

# %%
# Find unique values for each column
# To understand which column is categorical and which one is Continuous
H_Sales.nunique()
# Out:
# id               21436
# date               372
# price             4028
# bedrooms            13
# bathrooms           30
# sqft_living       1038
# sqft_lot          9782
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         946
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5034
# long               752
# sqft_living15      777
# sqft_lot15        8689
# dtype: int64

# %% [markdown]
# ### Below are the category of the features:

# %% [markdown]
# ##### Qualitative Features:
# - date - Qualitative Features
#
# - Categorical Features:
#
# - floors - Categorical Nominal feature
#
# - waterfront - Categorical Nominal feature
#
# - view - Categorical Ordinal feature
#
# - condition - Categorical Ordinal feature
#
# - grade - Categorical Ordinal feature
#
# - bedrooms - Categorical Nominal feature
#
# - bathrooms - Categorical Nominal feature
#
# ##### Quantitative Features:
# - all others are Quantitative Features.

# %% [markdown]
# ### Find and remove null values

# %%
#checking and removing null data
H_Sales.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# In the dataset, there are no missing values. It is not necessary for missing values to be present in the dataset in the form of NA, NAN, Zeroes, and so on; they could be represented by other values that can be explored by analyzing each feature.

# %%
H_Sales.shape
# Out:
# (21613, 21)

# %%
#checking for duplicate values
H_Sales.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Length: 21613, dtype: bool

# %%
#removing duplicates by checking the IDs
H_Sales.drop_duplicates(subset='id', keep='first', inplace=False, ignore_index=False)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0             1180      5650     1.0           0     0          3      7
# 1             2570      7242     2.0           0     0          3      7
# 2              770     10000     1.0           0     0          3      6
# 3             1960      5000     1.0           0     0          5      7
# 4             1680      8080     1.0           0     0          3      8
# ...            ...       ...     ...         ...   ...        ...    ...
# 21608         1530      1131     3.0           0     0          3      8
# 21609         2310      5813     2.0           0     0          3      8
# 21610         1020      1350     2.0           0     0          3      7
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21436 rows x 21 columns]

# %%
#Drop the columns "id" from axis 1

H_Sales = H_Sales.drop(['id','zipcode'], axis=1)

# %%
H_Sales.shape
# Out:
# (21613, 19)

# %% [markdown]
# ###  Identify outliers using the boxplot

# %%
# Identify outliers using the boxplot 
plt.figure(figsize=(20,12))

plt.subplot(331)
sns.boxplot(H_Sales.sqft_living)
plt.subplot(332)
sns.boxplot(H_Sales.bedrooms)
plt.subplot(333)
sns.boxplot(H_Sales.price)
plt.subplot(334)
sns.boxplot(H_Sales.sqft_lot)
plt.subplot(335)
sns.boxplot(H_Sales.bathrooms.astype('int'))
plt.show()

# %%
#Created a function to return the outliers
def detect_outliers(x, c = 1.5):
    q1, q3 = np.percentile(x, [25,75])
    #print("q1 - ",q1, " q3 - ", q3)
    
    iqr = (q3 - q1)
    #print("iqr --", iqr)
    
    lob = q1 - (iqr * c)
    #print("lob - ",lob)
    
    uob = q3 + (iqr * c)
    #print("uob - ",uob)
    
    # Generate outliers
    gen = np.where((x > uob) | (x < lob))

    return gen

# %%
# Detect all Outliers 
priceOutliers = detect_outliers(H_Sales['price'])
print("Total Outliers count : ",len(priceOutliers[0]))
# Out:
# Total Outliers count :  1146

# %% [markdown]
# ### Remove_outliers

# %%
# Remove outliers
H_Sales = H_Sales.drop(priceOutliers[0])

# %%
H_Sales.shape
# Out:
# (20467, 19)

# %% [markdown]
# ### Checking the price distribution as a target variable.

# %%
plt.figure(figsize=(8,6))
sns.distplot(H_Sales['price'])
plt.show()

# %% [markdown]
# - If the distribution of the target variable is too skewed, predictive modeling will be impossible. Although a normal bell curve is preferred, a slightly positive or negative skew is acceptable.

# %%
#Price without outlier
plt.figure(figsize=(8,6))
sns.boxplot(H_Sales['price'])
plt.show()

# %% [markdown]
# ### EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### Lets find out top 10 features which are highly correlaed with price.

# %% [markdown]
# Examining the data's correlation matrix. I'll explain the intended relationship between the variables using the heatmap.

# %%
H_Sales.corr()['price'].sort_values(ascending=False).head(10)
# Out:
# price            1.000000
# grade            0.631182
# sqft_living      0.622333
# sqft_living15    0.562090
# sqft_above       0.530451
# bathrooms        0.455927
# lat              0.430762
# bedrooms         0.296956
# floors           0.273987
# view             0.238268
# Name: price, dtype: float64

# %%
#Creating a correlation plot 
features = ['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'sqft_living15', 'sqft_lot15']

mask = np.zeros_like(H_Sales[features].corr(), dtype=np.bool) 
mask[np.triu_indices_from(mask)] = True 

f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation Matrix',fontsize=25)

sns.heatmap(H_Sales[features].corr(),linewidths=0.25,vmax=0.9,square=True,cmap="magma",
            linecolor='w',annot=True,annot_kws={"size":13},mask=mask,cbar_kws={"shrink": .9});

plt.show()

# %% [markdown]
# There is a high correlation between sqft_living and price. It seems that there is a positive linear relationship between the two. Going by general trend an increase in living space will lead to increase in price.from this we can see year renovated has tge low correlation.
# The dark blue color has correlation of 1 which is the price.
# There is a strong relationship between the price (target variable) and the number of bedrooms, bathrooms,sqft_living, floors, sqft_living15, grade, sqft_above, and sqft_basement.

# %% [markdown]
# ### Feature Engineering From Date

# %%
H_Sales['date'] = pd.to_datetime(H_Sales['date'])
H_Sales['month'] = H_Sales['date'].dt.month_name().str[:3]
H_Sales['year']=H_Sales['date'].apply(lambda date:date.year)

# %% [markdown]
# ### Relationships between the Features

# %%
fig, axs = plt.subplots( nrows=2, ncols=3, sharey=True, figsize=(18,12))
sns.scatterplot(y='price',x='sqft_living',data=H_Sales, hue='condition', palette='viridis', ax=axs[0,0])
sns.scatterplot(y='price',x='sqft_above',data=H_Sales, hue='condition', palette='viridis', ax=axs[0,1])
sns.scatterplot(y='price',x='sqft_living15',data=H_Sales, hue='condition', palette='viridis', ax=axs[0,2])
sns.scatterplot(y='price',x='sqft_basement',data=H_Sales, hue='condition', palette='viridis', ax=axs[1,0])
sns.scatterplot(y='price',x='sqft_lot',data=H_Sales, hue='condition', palette='viridis', ax=axs[1,1])
sns.scatterplot(y='price',x='sqft_lot15',data=H_Sales, hue='condition', palette='viridis', ax=axs[1,2])
plt.show()

# %% [markdown]
# There appears to be a strong positive correlation between sqft living, sqft above, and sqft living15 and price. This is not the case for sqft basement, sqft lot, and sqft lot15. It is self-evident that larger houses are more expensive. The graphs also show that the majority of houses lack a basement and land space, despite the fact that the price does not increase linearly with larger basement and land space. I discovered that sqft living is the sum of sqft above and sqft basement.
#
# sqft living = sqft above + sqft basement.

# %%
plt.figure(figsize = (6,4))
plt.title("\n Square feet above Price distribution\n",fontsize=20)
sns.distplot(H_Sales['sqft_above'])
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.title('Condition Vs Price', fontsize= 20)
sns.barplot(x='condition',y='price', data=H_Sales)
plt.show()

# %% [markdown]
# ### Are good-condition properties likely to increase in value?

# %%
plt.figure(figsize = (8,6))
sns.relplot(x='grade',y='price',hue='grade',alpha=0.7,height = 7,data=H_Sales)
plt.title("\n  Grade Vs Price\n",fontsize=18)
plt.show()

# %%
#living space
plt.figure(figsize = (12,8))
plt.title("\n Square living relationship with Price\n",fontsize=20)
sns.distplot(H_Sales['sqft_living'], color= 'darkgreen', label = 'data')

sns.regplot(x="sqft_living", y="price", data=H_Sales,color='darkgreen', label= ' Predicted Regression')
plt.show()

# %%
print('Mean',round(H_Sales['sqft_living'].mean(),2))
print('Median',H_Sales['sqft_living'].median())
print('Mode',H_Sales['sqft_living'].mode()[0])
# Out:
# Mean 1975.56
# Median 1860.0
# Mode 1300

# %% [markdown]
# The value of the property increases as we increase the living area of the house.

# %% [markdown]
# ### Does the view of the house impact the house prices?

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))
plt.title("\n Number of view\n",fontsize=20)
sns.countplot(x='view',data=H_Sales, palette='Set3', ax=axs[0])
sns.boxplot(y='price',x='view',data=H_Sales, palette='Set3', ax=axs[1])

plt.tight_layout()
plt.plot()
# Out:
# []

# %% [markdown]
# The view ranges from 0 to 4, indicating how good the property's view was. The graph above shows that the majority of houses have a good view, which explains why their prices are so low. Few houses have a view index of four, and they are quite pricey.

# %% [markdown]
# ### Does the Grade have any impact on the house prices ?

# %%
plt.figure(figsize= (8,6))
plt.title("\n Grade Distribution \n",fontsize=20)
sns.countplot(x='grade',data=H_Sales)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sns.countplot(x='grade',data=H_Sales, palette='Set3', ax=axs[0])
ax.set_xticklabels(ax.get_xticklabels(), rotation=60, ha="right")
sns.boxplot(y='price',x='grade',data=H_Sales, palette='Set3', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Does the waterfront property have any impact on the house prices ?

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sns.countplot(x='waterfront',data=H_Sales, palette='Set3', ax=axs[0])
sns.boxplot(y='price',x='waterfront',data=H_Sales, palette='Set3', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# - Waterfront houses seem to have an impact on prices
# - The median price reveals that certain waterfront properties are within reach of the average buyer.
# - waterfront - A dummy variable that indicates whether or not the apartment has a view of the water.
# - It goes without saying that properties with water views are usually pricey, but they are scarce.

# %% [markdown]
# ### Does the number of bedrooms impact the house prices?

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))
plt.title("\n Bedrooms Vs. Price\n",fontsize=20)
sns.countplot(x='bedrooms',data=H_Sales, palette='Set3',ax=axs[0])
sns.boxplot(y='price',x='bedrooms',data=H_Sales, palette='Set3', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# - Majority of these houses are two to five bedrooms, and also with large mansions with 33 beds. But we can't see it because the rest of the bedrooms number in the thousands and this is only one.
#
# - Another graph depicts the price distribution by bedroom. Bedrooms range in size from 3 to 7. That makes sense because, according to our count plot, the majority of the residences had between 3 and 7 bedrooms. As a result, the wide range of prices makes sense.

# %% [markdown]
# ### Does the number of bathrooms impact the house prices ?

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))
plt.title("\n Bathrooms Vs. Price\n",fontsize=20)
chart1 = sns.countplot(x='bathrooms',data=H_Sales, palette='Set3',ax=axs[0])
chart1.set_xticklabels(chart1.get_xticklabels(), rotation=90, horizontalalignment='right')

chart2 = sns.boxplot(y='price',x='bathrooms',data=H_Sales, palette='Set3', ax=axs[1])
chart2.set_xticklabels(chart2.get_xticklabels(), rotation=90, horizontalalignment='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Bathrooms--Most houses have 1 to 4 bathrooms, and their prices are lower than those with more than 4 bathrooms.
# - Actually, according to the headmap generated above, 'bathroom' is highly connected with'sqft living,' therefore I believe it is the size of the house, not the number of bathrooms, that makes it pricey.

# %% [markdown]
# ### Does the number of floors impact the house prices ?

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))
plt.title("\n Floors Vs. Price\n",fontsize=20)
sns.countplot(x='floors',data=H_Sales, palette='Set3',ax=axs[0])
sns.boxplot(y='price',x='floors',data=H_Sales, palette='Set3', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# - Large number of properties have only one floor, and only a few have a penthouse. However, this does not imply that high-rise buildings are more costly; other factors such as overall property size could also determine house prices.

# %%
H_Sales.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated      lat     long  sqft_living15  sqft_lot15 month  year
# 0             0  47.5112 -122.257           1340        5650   Oct  2014
# 1          1991  47.7210 -122.319           1690        7639   Dec  2014
# 2             0  47.7379 -122.233           2720        8062   Feb  2015
# 3             0  47.5208 -122.393           1360        5000   Dec  2014
# 4             0  47.6168 -122.045           1800        7503   Feb  2015

# %%
H_Sales.groupby('month').mean()['price']
# Out:
# month
# Apr    496743.607228
# Aug    476488.449919
# Dec    462681.430824
# Feb    455775.551464
# Jan    458157.891892
# Jul    483486.710388
# Jun    490758.805353
# Mar    479756.792325
# May    481255.155604
# Nov    462481.284650
# Oct    471639.307953
# Sep    473740.919811
# Name: price, dtype: float64

# %%
plt.figure(figsize= (10,8))
plt.title("\n Months relationship with Price\n",fontsize=20)
H_Sales.groupby('month').mean()['price'].plot()
plt.show()

# %%
plt.figure(figsize= (10,8))
plt.title("\n Year average Price\n",fontsize=20)
H_Sales.groupby('year').mean()['price'].plot(kind='line')
plt.show()

# %%
H_Sales['yr_renovated'].value_counts()
# Out:
# 0       19701
# 2014       82
# 2013       34
# 2000       30
# 2007       29
#         ...
# 1956        1
# 1948        1
# 1944        1
# 1934        1
# 1954        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
H_Sales['renovated'] = H_Sales['yr_renovated'].apply(lambda yr : 0 if yr==0 else 1)

# %%
H_Sales['renovated'].value_counts()
# Out:
# 0    19701
# 1      766
# Name: renovated, dtype: int64

# %% [markdown]
# - 19,701 unrenovated houses against 766 refurbished buildings. The plot below indicates that renovated properties are pricey.

# %%
fig, axs = plt.subplots(ncols=2, figsize=(12,6))

sns.countplot(x='renovated',data=H_Sales, palette='Set2',ax=axs[0])
sns.boxplot(y='price',x='renovated',data=H_Sales, palette='Set2', ax=axs[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Map of King County’s House

# %%
def generateBaseMap(map_location=[47.5,-122.161], zoom=9):
    base_map = folium.Map(location=map_location, control_scale=True, zoom_start=zoom)
    return base_map

# %%
from folium.plugins import HeatMap
H_Sales = H_Sales[np.logical_and(H_Sales.yr_built<=1980,H_Sales.yr_built >= 1970)] 
H_Sales['count'] = 1
base_map = generateBaseMap()
HeatMap(data=H_Sales[['lat', 'long', 'count']].groupby(['lat', 'long']).sum().reset_index().values.tolist(), radius=8, max_zoom=8).add_to(base_map)
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#longitude and latitude 

plt.figure(figsize=(15,10))
ax = sns.scatterplot(data=H_Sales, 
                x="long", 
                y="lat", 
                hue="price",
                hue_norm=(0, 550000),
                size='price', 
                sizes=(10, 200))
ax.set_title('House Price distribution', fontsize=23)
plt.show()

# %% [markdown]
# We can also see the price distribution is located large around the waterfronts like Kirkland, Kenmore, Bellevue

# %%
# Limit the display columns 
pd.options.display.max_columns = 999

# create numerical variable list
feat = ['price','bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 
                'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long', ]

# %%
H_Sales_preprocessing = H_Sales.loc[:, feat]
H_Sales_preprocessing.head()
# Out:
#         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 13   400000.0         3       1.75         1370      9680     1.0           0
# 15   650000.0         4       3.00         2950      5000     2.0           0
# 62   505000.0         3       1.75         2519      8690     2.0           0
# 64   425000.0         3       2.25         1660      6000     1.0           0
# 70  1040000.0         5       3.25         4770     50094     1.0           0
#
#     view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 13     0          4      7        1370              0      1977             0
# 15     3          3      9        1980            970      1979             0
# 62     0          5      8        2519              0      1973             0
# 64     0          3      7        1110            550      1979             0
# 70     0          4     11        3070           1700      1973             0
#
#         lat     long
# 13  47.6127 -122.045
# 15  47.5714 -122.375
# 62  47.4428 -122.344
# 64  47.6113 -122.297
# 70  47.6525 -122.160

# %%
# check correlation with an absolute value around
abs(H_Sales_preprocessing.corr()) > 0.60
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# price           True     False      False         True     False   False
# bedrooms       False      True      False        False     False   False
# bathrooms      False     False       True         True     False   False
# sqft_living     True     False       True         True     False   False
# sqft_lot       False     False      False        False      True   False
# floors         False     False      False        False     False    True
# waterfront     False     False      False        False     False   False
# view           False     False      False        False     False   False
# condition      False     False      False        False     False   False
# grade           True     False      False         True     False   False
# sqft_above     False     False      False         True     False    True
# sqft_basement  False     False      False        False     False   False
# yr_built       False     False      False        False     False   False
# yr_renovated   False     False      False        False     False   False
# lat            False     False      False        False     False   False
# long           False     False      False        False     False   False
#
#                waterfront   view  condition  grade  sqft_above  sqft_basement  \
# price               False  False      False   True       False          False
# bedrooms            False  False      False  False       False          False
# bathrooms           False  False      False  False       False          False
# sqft_living         False  False      False   True        True          False
# sqft_lot            False  False      False  False       False          False
# floors              False  False      False  False        True          False
# waterfront           True  False      False  False       False          False
# view                False   True      False  False       False          False
# condition           False  False       True  False       False          False
# grade               False  False      False   True       False          False
# sqft_above          False  False      False  False        True          False
# sqft_basement       False  False      False  False       False           True
# yr_built            False  False      False  False       False          False
# yr_renovated        False  False      False  False       False          False
# lat                 False  False      False  False       False          False
# long                False  False      False  False       False          False
#
#                yr_built  yr_renovated    lat   long
# price             False         False  False  False
# bedrooms          False         False  False  False
# bathrooms         False         False  False  False
# sqft_living       False         False  False  False
# sqft_lot          False         False  False  False
# floors            False         False  False  False
# waterfront        False         False  False  False
# view              False         False  False  False
# condition         False         False  False  False
# grade             False         False  False  False
# sqft_above        False         False  False  False
# sqft_basement     False         False  False  False
# yr_built           True         False  False  False
# yr_renovated      False          True  False  False
# lat               False         False   True  False
# long              False         False  False   True

# %%
# saving the absolute value of correlation matrix as a data frame
H_Sales = H_Sales_preprocessing.corr().abs().stack().reset_index().sort_values(0, ascending=False)
# zip the variable name columns in a new column
H_Sales['pairs'] = list(zip(H_Sales.level_0, H_Sales.level_1))
#set the index
H_Sales.set_index(['pairs'], inplace = True)
#d rop level colums
H_Sales.drop(columns=['level_1', 'level_0'], inplace = True)

# cc for correlation coefficient
H_Sales.columns = ['cc']
# dropped the dublicates
H_Sales.drop_duplicates(inplace=True)

H_Sales[(H_Sales.cc>.60) & (H_Sales.cc<1)]
# Out:
#                                  cc
# pairs
# (sqft_above, sqft_living)  0.733776
# (bathrooms, sqft_living)   0.692203
# (price, grade)             0.648124
# (sqft_living, price)       0.644485
# (floors, sqft_above)       0.643785
# (sqft_living, grade)       0.621447

# %%
H_Sales_preprocessing = H_Sales_preprocessing.drop(['sqft_living'], axis=1)
H_Sales_preprocessing
# Out:
#            price  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# 13      400000.0         3       1.75      9680     1.0           0     0
# 15      650000.0         4       3.00      5000     2.0           0     3
# 62      505000.0         3       1.75      8690     2.0           0     0
# 64      425000.0         3       2.25      6000     1.0           0     0
# 70     1040000.0         5       3.25     50094     1.0           0     0
# ...          ...       ...        ...       ...     ...         ...   ...
# 20057   434900.0         3       2.00      5040     2.0           0     0
# 20254   278000.0         2       2.25      1968     2.0           0     0
# 20447   356999.0         3       1.50      1546     2.0           0     0
# 20678   293000.0         2       2.25      1968     2.0           0     0
# 20747   265000.0         2       1.50      3427     2.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 13             4      7        1370              0      1977             0
# 15             3      9        1980            970      1979             0
# 62             5      8        2519              0      1973             0
# 64             3      7        1110            550      1979             0
# 70             4     11        3070           1700      1973             0
# ...          ...    ...         ...            ...       ...           ...
# 20057          3      7        1520              0      1977          2006
# 20254          4      7        1610              0      1979             0
# 20447          3      8        1010              0      1971          2014
# 20678          4      7        1610              0      1979             0
# 20747          3      7        1084              0      1976             0
#
#            lat     long
# 13     47.6127 -122.045
# 15     47.5714 -122.375
# 62     47.4428 -122.344
# 64     47.6113 -122.297
# 70     47.6525 -122.160
# ...        ...      ...
# 20057  47.7770 -122.362
# 20254  47.5184 -122.196
# 20447  47.5998 -122.311
# 20678  47.5184 -122.196
# 20747  47.7117 -122.326
#
# [2442 rows x 15 columns]

# %% [markdown]
# ## Model Development

# %% [markdown]
# ### Linear Regression
# Linear Regression Analysis consists of more than just fitting a linear line through a cloud of data points. It consists of 3 stages. I will be;
# - estimating the model, i.e., fitting the line, and
# - evaluating the validity and usefulness of the model.
#
# ### Regressions Performed
#
# #### Simple Linear Regression:
#
# - 'bedrooms' vs 'price'
# - 'grade' vs 'price'
#
# #### Multiple Regression:
#
# - 'bedrooms','grade', 'sqft_living', 'sqft_above'
# - 'bedrooms','bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'grade', 'sqft_above', 'sqft_basement', 'lat', 'sqft_living15'
#
# #### Polynomial Regression:
#
# - degree=2
# - degree=3

# %% [markdown]
# #### Assumption
# 1. Linearrity:The relationship between  X and the mean y is linear
# 2. Normality: Normal distribution
# 3. Homoscedasticty: Variance of the residual is the same  for any value of X
# 4. independence: obsevartions are independent of each other.

# %% [markdown]
# ### Import Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# ### Simple Regression Model

# %%
#Simple linear model
X =H_Sales_preprocessing['bedrooms']
y = H_Sales_preprocessing['price']
basicmodel = sm.OLS(y, X).fit()
basicmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.850
# Model:                            OLS   Adj. R-squared (uncentered):              0.849
# Method:                 Least Squares   F-statistic:                          1.378e+04
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        21:52:05   Log-Likelihood:                         -33176.
# No. Observations:                2442   AIC:                                  6.635e+04
# Df Residuals:                    2441   BIC:                                  6.636e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# bedrooms    1.262e+05   1075.165    117.393      0.000    1.24e+05    1.28e+05
# ==============================================================================
# Omnibus:                      148.332   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.619
# Skew:                           0.584   Prob(JB):                     8.14e-41
# Kurtosis:                       3.670   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#basic linear model
X =H_Sales_preprocessing['grade']
y = H_Sales_preprocessing['price']
basicmodel = sm.OLS(y, X).fit()
basicmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  price   R-squared (uncentered):                   0.886
# Model:                            OLS   Adj. R-squared (uncentered):              0.886
# Method:                 Least Squares   F-statistic:                          1.904e+04
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        21:52:05   Log-Likelihood:                         -32833.
# No. Observations:                2442   AIC:                                  6.567e+04
# Df Residuals:                    2441   BIC:                                  6.567e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# grade       6.109e+04    442.749    137.976      0.000    6.02e+04     6.2e+04
# ==============================================================================
# Omnibus:                      219.942   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.549
# Skew:                           0.802   Prob(JB):                     1.20e-61
# Kurtosis:                       3.432   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Linear Regression

# %%
X=H_Sales_preprocessing.drop(['price'], axis =1)
y = H_Sales_preprocessing['price']

# %%
#splitting to training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state = 4)

# %%
#create a linear regressor
lm = LinearRegression()
reg=linear_model.LinearRegression()
#train the model using the training set
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_train)

# %% [markdown]
# ### Multiple Regression

# %% [markdown]
# ### Linear regression: Model Evaluation

# %%
#model evaluation
print('R^2:',metrics.r2_score(y_train, y_pred))
print('Model_1')
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_train, y_pred))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_train, y_pred))
print('MSE:',metrics.mean_squared_error(y_train, y_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
print('intercept',lm.intercept_)
# Out:
# R^2: 0.6965190228999936
# Model_1
# Adjusted R^2: 0.6940109156512332
# MAE: 81533.25453647051
# MSE: 11736512022.265848
# RMSE: 108335.18367670702
# intercept -11287594.56749223

# %%
X_train.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'waterfront', 'view',
#        'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'lat', 'long'],
#       dtype='object')

# %%
# Coefficent
Coefdata = zip(X_train.columns, lm.coef_)
sorted(list(Coefdata), key=lambda x : x[1])
# Out:
# [('yr_built', -2818.470243188361),
#  ('bedrooms', -1973.8092172936624),
#  ('sqft_lot', 0.18634937910064764),
#  ('yr_renovated', 68.0900342086928),
#  ('sqft_basement', 83.27878692056197),
#  ('sqft_above', 92.90618161913244),
#  ('bathrooms', 8216.462391955924),
#  ('floors', 12317.946873249335),
#  ('view', 35264.42526040884),
#  ('condition', 39051.12694799401),
#  ('long', 57906.28806478548),
#  ('grade', 87694.05393033334),
#  ('waterfront', 98473.89351071398),
#  ('lat', 491222.7215291609)]

# %% [markdown]
# #### Cross Value Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# checking models performance error
scores = cross_val_score(lm, X_test, y_test, cv=3)
# root mean square error
display(scores)
display(scores.mean())
display(scores.std())
# Out:
# array([0.70317934, 0.61284629, 0.71790173])
# 0.677975783354304
# 0.046444058391206376

# %%
#visualizing the difference between actual prices and predicted values
plt.figure(figsize=(8,6))
plt. scatter(y_train, y_pred, color = 'blue')
plt.xlabel("House prices")
plt.ylabel("Predicted House Prices")
plt.title("Actual Prices Vs Predicted Prices")
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_pred,y_train-y_pred, color = "blue")
plt.xlabel("Predicted House Prices")
plt.ylabel("Residuals House Prices")
plt.title("Predicted Prices vs Residuals Prices")
plt.show()

# %%
#Check Normality of error
plt.figure(figsize=(8,6))
sns.distplot(y_train-y_pred)
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.title("Histogram of Residuals Prices")
plt.show()

# %% [markdown]
# This is a slightly right skewed, it might be as a result of outliner

# %% [markdown]
# ### Model evaluation

# %%
y_test_pred =lm.predict(X_test)

# %%
#model evaluation for ols
accu_linreg = metrics.r2_score(y_test, y_test_pred)
print('Model_2')
print('R^2:',accu_linreg)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
print('intercept',lm.intercept_)
# Out:
# Model_2
# R^2: 0.6776475752514319
# Adjusted R^2: 0.6713621519276437
# MAE: 81509.02365086533
# MSE: 11531237733.551325
# RMSE: 107383.60085949495
# intercept -11287594.56749223

# %%
X_test.columns
zipdata = zip(X_test.columns, lm.coef_)
sorted(list(zipdata), key=lambda x : x[1])
# Out:
# [('yr_built', -2818.470243188361),
#  ('bedrooms', -1973.8092172936624),
#  ('sqft_lot', 0.18634937910064764),
#  ('yr_renovated', 68.0900342086928),
#  ('sqft_basement', 83.27878692056197),
#  ('sqft_above', 92.90618161913244),
#  ('bathrooms', 8216.462391955924),
#  ('floors', 12317.946873249335),
#  ('view', 35264.42526040884),
#  ('condition', 39051.12694799401),
#  ('long', 57906.28806478548),
#  ('grade', 87694.05393033334),
#  ('waterfront', 98473.89351071398),
#  ('lat', 491222.7215291609)]

# %% [markdown]
# ## Model Evaluation and Refinement

# %% [markdown]
# ### Polynomial Regression Model

# %%
# importing polynomial features
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
polyfeat=PolynomialFeatures(degree=2)
xtrain_poly=polyfeat.fit_transform(X)
xtest_poly=polyfeat.fit_transform(X)
poly=linear_model.LinearRegression()

# %%
poly.fit(xtrain_poly,y)
polypred=poly.predict(xtrain_poly)

print('Model_3')
mean_squared_error = metrics.mean_squared_error(y, polypred)
print('Root Mean Squared Error (RMSE) ', round(np.sqrt(mean_squared_error), 2))
print('R-squared (training) ', round(poly.score(xtrain_poly, y), 3))
print('R-squared (testing) ', round(poly.score(xtest_poly, y), 3))
X_test.columns
zipdata = zip(X_test.columns, lm.coef_)
sorted(list(zipdata), key=lambda x : x[1])

print('Coefficients: \n', lm.coef_)
# Out:
# Model_3
# Root Mean Squared Error (RMSE)  92330.41
# R-squared (training)  0.775
# R-squared (testing)  0.775
# Coefficients:
#  [-1.97380922e+03  8.21646239e+03  1.86349379e-01  1.23179469e+04
#   9.84738935e+04  3.52644253e+04  3.90511269e+04  8.76940539e+04
#   9.29061816e+01  8.32787869e+01 -2.81847024e+03  6.80900342e+01
#   4.91222722e+05  5.79062881e+04]

# %%
X_test.columns
zipdata = zip(X_test.columns, lm.coef_)
sorted(list(zipdata), key=lambda x : x[1])
coeficient = pd.DataFrame(lm.coef_,index=X_test.columns,)
coefic
# Out:
#                            0
# bedrooms        -1973.809217
# bathrooms        8216.462392
# sqft_lot            0.186349
# floors          12317.946873
# waterfront      98473.893511
# view            35264.425260
# condition       39051.126948
# grade           87694.053930
# sqft_above         92.906182
# sqft_basement      83.278787
# yr_built        -2818.470243
# yr_renovated       68.090034
# lat            491222.721529
# long            57906.288065

# %% [markdown]
# - Model_3 gives us R-squared (testing) score of 0.775. From above reports, we can conclude that Polynomial regression is best solution.
# - The R-squared value for training data is 0.775, which is a great predictor of accuracy.

# %% [markdown]
# ### Building Constant Model

# %%
#Creating a constant model
pred=sm.add_constant(X_train)
#X_Cons = pd.DataFrame(X_train)
result=sm.OLS(y_train, pred).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.697
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     277.7
# Date:                Sat, 10 Dec 2022   Prob (F-statistic):               0.00
# Time:                        21:52:07   Log-Likelihood:                -22237.
# No. Observations:                1709   AIC:                         4.450e+04
# Df Residuals:                    1694   BIC:                         4.459e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -1.129e+07   3.58e+06     -3.154      0.002   -1.83e+07   -4.27e+06
# bedrooms      -1973.8092   4127.425     -0.478      0.633   -1.01e+04    6121.578
# bathrooms      8216.4624   6735.692      1.220      0.223   -4994.690    2.14e+04
# sqft_lot          0.1863      0.065      2.868      0.004       0.059       0.314
# floors         1.232e+04   9057.270      1.360      0.174   -5446.669    3.01e+04
# waterfront     9.847e+04   4.74e+04      2.079      0.038    5584.449    1.91e+05
# view           3.526e+04   4402.575      8.010      0.000    2.66e+04    4.39e+04
# condition      3.905e+04   4214.282      9.266      0.000    3.08e+04    4.73e+04
# grade          8.769e+04   4398.162     19.939      0.000    7.91e+04    9.63e+04
# sqft_above       92.9062      8.110     11.456      0.000      77.000     108.813
# sqft_basement    83.2788      8.156     10.211      0.000      67.282      99.275
# yr_built      -2818.4702    975.527     -2.889      0.004   -4731.836    -905.104
# yr_renovated     68.0900     10.730      6.346      0.000      47.044      89.136
# lat            4.912e+05   1.77e+04     27.763      0.000    4.57e+05    5.26e+05
# long           5.791e+04   2.14e+04      2.705      0.007    1.59e+04    9.99e+04
# ==============================================================================
# Omnibus:                      186.942   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.802
# Skew:                           0.743   Prob(JB):                     9.78e-70
# Kurtosis:                       4.501   Cond. No.                     6.62e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.62e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sm.graphics.qqplot(result.resid, line='45',fit=True);

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Constant model shows  R-squared value has from  0.697 also the base model wasn't normally distributed.
# - The polynomial model show R-squared has 0.775
# - The latitude coefficient is 491,200 -- which means I assume, if the house around certain location with price is higher than other areas.
#
# - The number of bathroom also had significant impact on prices with the 8,216.46
#
# - The King county grading system also impacted the house price. The coeffient is 87,690
# - The conditions of the homes also impacted the price, The  coefficient is 39,0504

# %% [markdown]
# ### Next Step

# %% [markdown]
# Future work would need more insight into how zipcode influenced house prices, as the amount of houses in specific zipcodes have higher sales prices. To determine the validity of the data further, I will use the polynomial regression model.
